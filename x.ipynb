# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# load datset into data
data = pd.read_csv('california.csv')
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
# check for null value
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   ocean_proximity     20640 non-null  object
#  9   median_house_value  20640 non-null  int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  int64
#  3   total_rooms         20433 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  int64
#  6   households          20433 non-null  int64
#  7   median_income       20433 non-null  float64
#  8   ocean_proximity     20433 non-null  object
#  9   median_house_value  20433 non-null  int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

x = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

# %%
# train test data split into 20 80 ratio
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.2)

# %%
#Comvine ytrain data after spliting
train_data = X_train.join(Y_train)
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4827     -118.32     34.03                  31         2206           501.0
# 1848     -122.27     37.91                  47         1930           315.0
# 1607     -122.08     37.87                  24         6130          1359.0
# 6314     -117.98     34.01                  27         2643           418.0
# 14981    -116.99     32.72                  15          825           130.0
# ...          ...       ...                 ...          ...             ...
# 18835    -122.64     41.74                  33         2644           459.0
# 4993     -118.31     33.99                  44         1703           358.0
# 1645     -121.89     37.82                   4        11444          1355.0
# 2222     -119.83     36.82                  14         1087           165.0
# 12399    -116.31     33.67                  11         4686           851.0
#
# ...

# %%
train_data.hist(figsize =(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
# fixed the plot size 
plt.figure(figsize=(15,8))

# drop the ocean proximity bcz w'are doing corellation MATRIX of train_data
train_dataa = train_data.drop(['ocean_proximity'], axis=1)

sns.heatmap(train_dataa.corr(), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)
train_data['population'] = np.log(train_data['population'] + 1)
train_data['households'] = np.log(train_data['households'] + 1)

train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
# get ocean proximity into categorical feature.
ocean = pd.get_dummies(train_data.ocean_proximity)
ocean
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 4827        True   False   False     False       False
# 1848       False   False   False      True       False
# 1607       False   False   False      True       False
# 6314        True   False   False     False       False
# 14981       True   False   False     False       False
# ...          ...     ...     ...       ...         ...
# 18835      False    True   False     False       False
# 4993        True   False   False     False       False
# 1645       False    True   False     False       False
# 2222       False    True   False     False       False
# 12399      False    True   False     False       False
#
# [16346 rows x 5 columns]

# %%
# join those categorical data into train data
train_data = train_data.join(ocean)

#drop ocean proximity from train rata bcz we already divided ocean proximity into categorical from so we don't need ocen proximity.
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4827     -118.32     34.03                  31     7.699389        6.218600
# 1848     -122.27     37.91                  47     7.565793        5.755742
# 1607     -122.08     37.87                  24     8.721113        7.215240
# 6314     -117.98     34.01                  27     7.880048        6.037871
# 14981    -116.99     32.72                  15     6.716595        4.875197
# ...          ...       ...                 ...          ...             ...
# 18835    -122.64     41.74                  33     7.880426        6.131226
# 4993     -118.31     33.99                  44     7.440734        5.883322
# 1645     -121.89     37.82                   4     9.345308        7.212294
# 2222     -119.83     36.82                  14     6.992096        5.111988
# 12399    -116.31     33.67                  11     8.452548        6.747587
#
# ...
